# %% [markdown]
# ## No Regularisation

# %%
import torch
import PIL

import torchvision
import torchvision.transforms as transforms

import torch.optim as optim
import torch.nn as nn

print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# CUDA available: True

# %%
if torch.cuda.is_available():
  device = "cuda"
else:
  device = "cpu"

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5, ), (0.5, ))])

# %%
trainset = torchvision.datasets.FashionMNIST(root="./data",
                                             train=True,
                                             download=True,
                                             transform=transform)

testset = torchvision.datasets.FashionMNIST(root="./data",
                                            train=False,
                                            download=True,
                                            transform=transform)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:00<00:00, 105053637.13it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 5018847.10it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 11090466.13it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 4483446.22it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False, num_workers=2)

classes = ('T-shirt/top', 'Trouser', 'Pullover', 'Dress',
           'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot')

# %%
print(trainset.data.shape)
print(testset.data.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([10000, 28, 28])

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
num_of_images = 50

for index in range(1, num_of_images + 1):
  plt.subplot(5, 10, index)
  plt.axis("off")
  plt.imshow(trainset.data[index], cmap="gray_r")

# %%
import numpy as np

def imshow(img):
  img = img / 2 + 0.5
  npimg = img.numpy()
  plt.imshow(np.transpose(npimg, (1, 2, 0)))
  plt.show()

dataiter = iter(trainloader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images))

print(" ".join("%5s" % classes[labels[j]] for j in range(8)))
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Dress T-shirt/top Sandal Sneaker Shirt T-shirt/top Ankle boot  Coat

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.conv1 = nn.Conv2d(1, 32, 3)
    self.conv2 = nn.Conv2d(32, 64, 3)
    self.pool = nn.MaxPool2d(2, 2)
    self.fc1 = nn.Linear(64*12*12, 128)
    self.fc2 = nn.Linear(128, 10)

  def forward(self, x):
    x = F.relu(self.conv1(x))
    x = self.pool(F.relu(self.conv2(x)))
    x = x.view(-1, 64*12*12)
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return x

net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
epochs = 15

epoch_log = []
loss_log = []
accuracy_log = []

for epoch in range(epochs):
  print(f"Starting Epoch: {epoch+1}...")
  running_loss = 0.0
  for i, data in enumerate(trainloader, 0):
    inputs, labels = data
    inputs = inputs.to(device)
    labels = labels.to(device)
    optimizer.zero_grad()
    outputs = net(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    running_loss += loss.item()
    if i%100 == 99:
      correct = 0
      total = 0

      with torch.no_grad():
        for data in testloader:
          images, labels = data
          images = images.to(device)
          labels = labels.to(device)

          outputs = net(images)

          _, predicted = torch.max(outputs.data, 1)

          total += labels.size(0)
          correct += (predicted == labels).sum().item()
        accuracy = 100*correct/total
        epoch_num = epoch+1
        actual_loss = running_loss / 50
        print(f"Epoch: {epoch_num}, Mini-Batch Completed: {(i+1)}, Loss: {actual_loss:.3f}, Test Accuracy = {accuracy:.3f}%")
        running_loss = 0.0
  epoch_log.append(epoch_num)
  loss_log.append(actual_loss)
  accuracy_log.append(accuracy)

print("Finished Training")
# Out:
# Starting Epoch: 1...
# Epoch: 1, Mini-Batch Completed: 100, Loss: 4.152, Test Accuracy = 56.880%
# Epoch: 1, Mini-Batch Completed: 200, Loss: 2.038, Test Accuracy = 72.410%
# Epoch: 1, Mini-Batch Completed: 300, Loss: 1.512, Test Accuracy = 73.550%
# Epoch: 1, Mini-Batch Completed: 400, Loss: 1.348, Test Accuracy = 75.930%
# Epoch: 1, Mini-Batch Completed: 500, Loss: 1.325, Test Accuracy = 73.930%
# Epoch: 1, Mini-Batch Completed: 600, Loss: 1.207, Test Accuracy = 76.610%
# Epoch: 1, Mini-Batch Completed: 700, Loss: 1.184, Test Accuracy = 75.870%
# Epoch: 1, Mini-Batch Completed: 800, Loss: 1.210, Test Accuracy = 77.670%
# Epoch: 1, Mini-Batch Completed: 900, Loss: 1.176, Test Accuracy = 74.200%
# Epoch: 1, Mini-Batch Completed: 1000, Loss: 1.136, Test Accuracy = 78.380%
# Epoch: 1, Mini-Batch Completed: 1100, Loss: 1.084, Test Accuracy = 79.250%
# Epoch: 1, Mini-Batch Completed: 1200, Loss: 1.033, Test Accuracy = 79.960%
# Epoch: 1, Mini-Batch Completed: 1300, Loss: 1.054, Test Accuracy = 80.890%
# Epoch: 1, Mini-Batch Completed: 1400, Loss: 1.064, Test Accuracy = 79.800%
# Epoch: 1, Mini-Batch Completed: 1500, Loss: 1.025, Test Accuracy = 80.350%
# Epoch: 1, Mini-Batch Completed: 1600, Loss: 0.996, Test Accuracy = 81.000%
# Epoch: 1, Mini-Batch Completed: 1700, Loss: 1.014, Test Accuracy = 81.670%
# Epoch: 1, Mini-Batch Completed: 1800, Loss: 1.005, Test Accuracy = 82.000%
# Starting Epoch: 2...
# Epoch: 2, Mini-Batch Completed: 100, Loss: 0.997, Test Accuracy = 81.950%
# Epoch: 2, Mini-Batch Completed: 200, Loss: 0.915, Test Accuracy = 82.790%
# Epoch: 2, Mini-Batch Completed: 300, Loss: 0.927, Test Accuracy = 82.170%
# Epoch: 2, Mini-Batch Completed: 400, Loss: 0.944, Test Accuracy = 82.410%
# Epoch: 2, Mini-Batch Completed: 500, Loss: 0.885, Test Accuracy = 82.970%
# Epoch: 2, Mini-Batch Completed: 600, Loss: 0.895, Test Accuracy = 82.740%
# Epoch: 2, Mini-Batch Completed: 700, Loss: 0.847, Test Accuracy = 82.990%
# Epoch: 2, Mini-Batch Completed: 800, Loss: 0.895, Test Accuracy = 82.960%
# Epoch: 2, Mini-Batch Completed: 900, Loss: 0.890, Test Accuracy = 82.700%
# Epoch: 2, Mini-Batch Completed: 1000, Loss: 0.795, Test Accuracy = 83.180%
# Epoch: 2, Mini-Batch Completed: 1100, Loss: 0.861, Test Accuracy = 84.240%
# Epoch: 2, Mini-Batch Completed: 1200, Loss: 0.852, Test Accuracy = 84.760%
# Epoch: 2, Mini-Batch Completed: 1300, Loss: 0.840, Test Accuracy = 82.370%
# Epoch: 2, Mini-Batch Completed: 1400, Loss: 0.818, Test Accuracy = 84.170%
# Epoch: 2, Mini-Batch Completed: 1500, Loss: 0.846, Test Accuracy = 84.390%
# Epoch: 2, Mini-Batch Completed: 1600, Loss: 0.843, Test Accuracy = 84.400%
# Epoch: 2, Mini-Batch Completed: 1700, Loss: 0.787, Test Accuracy = 84.890%
# Epoch: 2, Mini-Batch Completed: 1800, Loss: 0.795, Test Accuracy = 84.950%
# Starting Epoch: 3...
# Epoch: 3, Mini-Batch Completed: 100, Loss: 0.765, Test Accuracy = 85.530%
# Epoch: 3, Mini-Batch Completed: 200, Loss: 0.726, Test Accuracy = 85.030%
# Epoch: 3, Mini-Batch Completed: 300, Loss: 0.768, Test Accuracy = 84.800%
# Epoch: 3, Mini-Batch Completed: 400, Loss: 0.711, Test Accuracy = 86.230%
# Epoch: 3, Mini-Batch Completed: 500, Loss: 0.737, Test Accuracy = 86.030%
# Epoch: 3, Mini-Batch Completed: 600, Loss: 0.741, Test Accuracy = 86.190%
# Epoch: 3, Mini-Batch Completed: 700, Loss: 0.747, Test Accuracy = 84.590%
# Epoch: 3, Mini-Batch Completed: 800, Loss: 0.683, Test Accuracy = 86.610%
# Epoch: 3, Mini-Batch Completed: 900, Loss: 0.693, Test Accuracy = 85.740%
# Epoch: 3, Mini-Batch Completed: 1000, Loss: 0.777, Test Accuracy = 84.860%
# Epoch: 3, Mini-Batch Completed: 1100, Loss: 0.714, Test Accuracy = 86.310%
# Epoch: 3, Mini-Batch Completed: 1200, Loss: 0.703, Test Accuracy = 86.260%
# Epoch: 3, Mini-Batch Completed: 1300, Loss: 0.718, Test Accuracy = 85.370%
# Epoch: 3, Mini-Batch Completed: 1400, Loss: 0.695, Test Accuracy = 86.630%
# Epoch: 3, Mini-Batch Completed: 1500, Loss: 0.705, Test Accuracy = 86.880%
# Epoch: 3, Mini-Batch Completed: 1600, Loss: 0.723, Test Accuracy = 86.590%
# Epoch: 3, Mini-Batch Completed: 1700, Loss: 0.704, Test Accuracy = 86.900%
# Epoch: 3, Mini-Batch Completed: 1800, Loss: 0.773, Test Accuracy = 86.560%
# Starting Epoch: 4...
# Epoch: 4, Mini-Batch Completed: 100, Loss: 0.692, Test Accuracy = 86.990%
# Epoch: 4, Mini-Batch Completed: 200, Loss: 0.628, Test Accuracy = 86.970%
# Epoch: 4, Mini-Batch Completed: 300, Loss: 0.676, Test Accuracy = 86.860%
# Epoch: 4, Mini-Batch Completed: 400, Loss: 0.658, Test Accuracy = 86.570%
# Epoch: 4, Mini-Batch Completed: 500, Loss: 0.648, Test Accuracy = 87.710%
# Epoch: 4, Mini-Batch Completed: 600, Loss: 0.629, Test Accuracy = 87.260%
# Epoch: 4, Mini-Batch Completed: 700, Loss: 0.636, Test Accuracy = 87.460%
# Epoch: 4, Mini-Batch Completed: 800, Loss: 0.598, Test Accuracy = 86.220%
# Epoch: 4, Mini-Batch Completed: 900, Loss: 0.604, Test Accuracy = 87.620%
# Epoch: 4, Mini-Batch Completed: 1000, Loss: 0.641, Test Accuracy = 87.240%
# Epoch: 4, Mini-Batch Completed: 1100, Loss: 0.614, Test Accuracy = 87.270%
# Epoch: 4, Mini-Batch Completed: 1200, Loss: 0.644, Test Accuracy = 87.890%
# Epoch: 4, Mini-Batch Completed: 1300, Loss: 0.616, Test Accuracy = 87.900%
# Epoch: 4, Mini-Batch Completed: 1400, Loss: 0.661, Test Accuracy = 87.220%
# Epoch: 4, Mini-Batch Completed: 1500, Loss: 0.647, Test Accuracy = 87.090%
# Epoch: 4, Mini-Batch Completed: 1600, Loss: 0.642, Test Accuracy = 87.840%
# Epoch: 4, Mini-Batch Completed: 1700, Loss: 0.660, Test Accuracy = 87.080%
# Epoch: 4, Mini-Batch Completed: 1800, Loss: 0.625, Test Accuracy = 87.500%
# Starting Epoch: 5...
# Epoch: 5, Mini-Batch Completed: 100, Loss: 0.629, Test Accuracy = 88.110%
# Epoch: 5, Mini-Batch Completed: 200, Loss: 0.602, Test Accuracy = 88.460%
# Epoch: 5, Mini-Batch Completed: 300, Loss: 0.573, Test Accuracy = 87.990%
# Epoch: 5, Mini-Batch Completed: 400, Loss: 0.560, Test Accuracy = 88.200%
# Epoch: 5, Mini-Batch Completed: 500, Loss: 0.591, Test Accuracy = 88.210%
# Epoch: 5, Mini-Batch Completed: 600, Loss: 0.582, Test Accuracy = 87.740%
# Epoch: 5, Mini-Batch Completed: 700, Loss: 0.571, Test Accuracy = 88.190%
# Epoch: 5, Mini-Batch Completed: 800, Loss: 0.596, Test Accuracy = 88.080%
# Epoch: 5, Mini-Batch Completed: 900, Loss: 0.565, Test Accuracy = 88.120%
# Epoch: 5, Mini-Batch Completed: 1000, Loss: 0.584, Test Accuracy = 88.680%
# Epoch: 5, Mini-Batch Completed: 1100, Loss: 0.576, Test Accuracy = 88.280%
# Epoch: 5, Mini-Batch Completed: 1200, Loss: 0.616, Test Accuracy = 88.610%
# Epoch: 5, Mini-Batch Completed: 1300, Loss: 0.571, Test Accuracy = 86.890%
# Epoch: 5, Mini-Batch Completed: 1400, Loss: 0.575, Test Accuracy = 87.990%
# Epoch: 5, Mini-Batch Completed: 1500, Loss: 0.584, Test Accuracy = 88.300%
# Epoch: 5, Mini-Batch Completed: 1600, Loss: 0.594, Test Accuracy = 88.920%
# Epoch: 5, Mini-Batch Completed: 1700, Loss: 0.571, Test Accuracy = 87.870%
# Epoch: 5, Mini-Batch Completed: 1800, Loss: 0.581, Test Accuracy = 88.110%
# Starting Epoch: 6...
# Epoch: 6, Mini-Batch Completed: 100, Loss: 0.552, Test Accuracy = 89.000%
# Epoch: 6, Mini-Batch Completed: 200, Loss: 0.553, Test Accuracy = 88.640%
# Epoch: 6, Mini-Batch Completed: 300, Loss: 0.556, Test Accuracy = 88.900%
# Epoch: 6, Mini-Batch Completed: 400, Loss: 0.533, Test Accuracy = 88.770%
# Epoch: 6, Mini-Batch Completed: 500, Loss: 0.513, Test Accuracy = 89.260%
# Epoch: 6, Mini-Batch Completed: 600, Loss: 0.564, Test Accuracy = 89.030%
# Epoch: 6, Mini-Batch Completed: 700, Loss: 0.524, Test Accuracy = 88.080%
# Epoch: 6, Mini-Batch Completed: 800, Loss: 0.551, Test Accuracy = 88.680%
# Epoch: 6, Mini-Batch Completed: 900, Loss: 0.544, Test Accuracy = 89.510%
# Epoch: 6, Mini-Batch Completed: 1000, Loss: 0.532, Test Accuracy = 88.130%
# Epoch: 6, Mini-Batch Completed: 1100, Loss: 0.534, Test Accuracy = 89.060%
# Epoch: 6, Mini-Batch Completed: 1200, Loss: 0.539, Test Accuracy = 89.040%
# Epoch: 6, Mini-Batch Completed: 1300, Loss: 0.541, Test Accuracy = 89.060%
# Epoch: 6, Mini-Batch Completed: 1400, Loss: 0.541, Test Accuracy = 89.080%
# Epoch: 6, Mini-Batch Completed: 1500, Loss: 0.544, Test Accuracy = 89.740%
# Epoch: 6, Mini-Batch Completed: 1600, Loss: 0.520, Test Accuracy = 89.740%
# Epoch: 6, Mini-Batch Completed: 1700, Loss: 0.537, Test Accuracy = 89.640%
# Epoch: 6, Mini-Batch Completed: 1800, Loss: 0.551, Test Accuracy = 89.260%
# Starting Epoch: 7...
# Epoch: 7, Mini-Batch Completed: 100, Loss: 0.523, Test Accuracy = 89.240%
# Epoch: 7, Mini-Batch Completed: 200, Loss: 0.490, Test Accuracy = 89.070%
# Epoch: 7, Mini-Batch Completed: 300, Loss: 0.521, Test Accuracy = 89.130%
# Epoch: 7, Mini-Batch Completed: 400, Loss: 0.512, Test Accuracy = 89.660%
# Epoch: 7, Mini-Batch Completed: 500, Loss: 0.494, Test Accuracy = 89.570%
# Epoch: 7, Mini-Batch Completed: 600, Loss: 0.492, Test Accuracy = 89.180%
# Epoch: 7, Mini-Batch Completed: 700, Loss: 0.542, Test Accuracy = 89.770%
# Epoch: 7, Mini-Batch Completed: 800, Loss: 0.490, Test Accuracy = 89.380%
# Epoch: 7, Mini-Batch Completed: 900, Loss: 0.490, Test Accuracy = 89.790%
# Epoch: 7, Mini-Batch Completed: 1000, Loss: 0.509, Test Accuracy = 89.530%
# Epoch: 7, Mini-Batch Completed: 1100, Loss: 0.505, Test Accuracy = 89.620%
# Epoch: 7, Mini-Batch Completed: 1200, Loss: 0.491, Test Accuracy = 89.650%
# Epoch: 7, Mini-Batch Completed: 1300, Loss: 0.539, Test Accuracy = 89.860%
# Epoch: 7, Mini-Batch Completed: 1400, Loss: 0.514, Test Accuracy = 90.020%
# Epoch: 7, Mini-Batch Completed: 1500, Loss: 0.532, Test Accuracy = 90.160%
# Epoch: 7, Mini-Batch Completed: 1600, Loss: 0.491, Test Accuracy = 89.990%
# Epoch: 7, Mini-Batch Completed: 1700, Loss: 0.454, Test Accuracy = 89.540%
# Epoch: 7, Mini-Batch Completed: 1800, Loss: 0.491, Test Accuracy = 89.770%
# Starting Epoch: 8...
# Epoch: 8, Mini-Batch Completed: 100, Loss: 0.494, Test Accuracy = 89.080%
# Epoch: 8, Mini-Batch Completed: 200, Loss: 0.475, Test Accuracy = 89.480%
# Epoch: 8, Mini-Batch Completed: 300, Loss: 0.493, Test Accuracy = 89.910%
# Epoch: 8, Mini-Batch Completed: 400, Loss: 0.456, Test Accuracy = 89.250%
# Epoch: 8, Mini-Batch Completed: 500, Loss: 0.447, Test Accuracy = 89.520%
# Epoch: 8, Mini-Batch Completed: 600, Loss: 0.509, Test Accuracy = 89.690%
# Epoch: 8, Mini-Batch Completed: 700, Loss: 0.495, Test Accuracy = 89.780%
# Epoch: 8, Mini-Batch Completed: 800, Loss: 0.465, Test Accuracy = 90.190%
# Epoch: 8, Mini-Batch Completed: 900, Loss: 0.457, Test Accuracy = 89.780%
# Epoch: 8, Mini-Batch Completed: 1000, Loss: 0.452, Test Accuracy = 89.970%
# Epoch: 8, Mini-Batch Completed: 1100, Loss: 0.442, Test Accuracy = 89.930%
# Epoch: 8, Mini-Batch Completed: 1200, Loss: 0.466, Test Accuracy = 90.270%
# Epoch: 8, Mini-Batch Completed: 1300, Loss: 0.515, Test Accuracy = 90.230%
# Epoch: 8, Mini-Batch Completed: 1400, Loss: 0.483, Test Accuracy = 89.550%
# Epoch: 8, Mini-Batch Completed: 1500, Loss: 0.452, Test Accuracy = 90.280%
# Epoch: 8, Mini-Batch Completed: 1600, Loss: 0.470, Test Accuracy = 89.480%
# Epoch: 8, Mini-Batch Completed: 1700, Loss: 0.516, Test Accuracy = 90.160%
# Epoch: 8, Mini-Batch Completed: 1800, Loss: 0.439, Test Accuracy = 90.340%
# Starting Epoch: 9...
# Epoch: 9, Mini-Batch Completed: 100, Loss: 0.441, Test Accuracy = 89.770%
# Epoch: 9, Mini-Batch Completed: 200, Loss: 0.460, Test Accuracy = 89.660%
# Epoch: 9, Mini-Batch Completed: 300, Loss: 0.463, Test Accuracy = 90.080%
# Epoch: 9, Mini-Batch Completed: 400, Loss: 0.453, Test Accuracy = 89.690%
# Epoch: 9, Mini-Batch Completed: 500, Loss: 0.432, Test Accuracy = 89.690%
# Epoch: 9, Mini-Batch Completed: 600, Loss: 0.435, Test Accuracy = 89.980%
# Epoch: 9, Mini-Batch Completed: 700, Loss: 0.413, Test Accuracy = 89.150%
# Epoch: 9, Mini-Batch Completed: 800, Loss: 0.486, Test Accuracy = 90.640%
# Epoch: 9, Mini-Batch Completed: 900, Loss: 0.457, Test Accuracy = 89.970%
# Epoch: 9, Mini-Batch Completed: 1000, Loss: 0.494, Test Accuracy = 90.260%
# Epoch: 9, Mini-Batch Completed: 1100, Loss: 0.443, Test Accuracy = 90.600%
# Epoch: 9, Mini-Batch Completed: 1200, Loss: 0.442, Test Accuracy = 90.260%
# Epoch: 9, Mini-Batch Completed: 1300, Loss: 0.433, Test Accuracy = 89.990%
# Epoch: 9, Mini-Batch Completed: 1400, Loss: 0.482, Test Accuracy = 90.630%
# Epoch: 9, Mini-Batch Completed: 1500, Loss: 0.431, Test Accuracy = 90.380%
# Epoch: 9, Mini-Batch Completed: 1600, Loss: 0.424, Test Accuracy = 90.550%
# Epoch: 9, Mini-Batch Completed: 1700, Loss: 0.416, Test Accuracy = 90.020%
# Epoch: 9, Mini-Batch Completed: 1800, Loss: 0.418, Test Accuracy = 89.650%
# Starting Epoch: 10...
# Epoch: 10, Mini-Batch Completed: 100, Loss: 0.399, Test Accuracy = 90.760%
# Epoch: 10, Mini-Batch Completed: 200, Loss: 0.389, Test Accuracy = 90.330%
# Epoch: 10, Mini-Batch Completed: 300, Loss: 0.409, Test Accuracy = 90.500%
# Epoch: 10, Mini-Batch Completed: 400, Loss: 0.437, Test Accuracy = 90.410%
# Epoch: 10, Mini-Batch Completed: 500, Loss: 0.422, Test Accuracy = 90.410%
# Epoch: 10, Mini-Batch Completed: 600, Loss: 0.431, Test Accuracy = 90.780%
# Epoch: 10, Mini-Batch Completed: 700, Loss: 0.387, Test Accuracy = 90.490%
# Epoch: 10, Mini-Batch Completed: 800, Loss: 0.418, Test Accuracy = 90.900%
# Epoch: 10, Mini-Batch Completed: 900, Loss: 0.397, Test Accuracy = 90.710%
# Epoch: 10, Mini-Batch Completed: 1000, Loss: 0.423, Test Accuracy = 89.750%
# Epoch: 10, Mini-Batch Completed: 1100, Loss: 0.460, Test Accuracy = 90.660%
# Epoch: 10, Mini-Batch Completed: 1200, Loss: 0.427, Test Accuracy = 90.250%
# Epoch: 10, Mini-Batch Completed: 1300, Loss: 0.437, Test Accuracy = 90.740%
# Epoch: 10, Mini-Batch Completed: 1400, Loss: 0.421, Test Accuracy = 90.090%
# Epoch: 10, Mini-Batch Completed: 1500, Loss: 0.425, Test Accuracy = 90.580%
# Epoch: 10, Mini-Batch Completed: 1600, Loss: 0.445, Test Accuracy = 90.360%
# Epoch: 10, Mini-Batch Completed: 1700, Loss: 0.458, Test Accuracy = 90.910%
# Epoch: 10, Mini-Batch Completed: 1800, Loss: 0.429, Test Accuracy = 90.900%
# Starting Epoch: 11...
# Epoch: 11, Mini-Batch Completed: 100, Loss: 0.396, Test Accuracy = 90.440%
# Epoch: 11, Mini-Batch Completed: 200, Loss: 0.397, Test Accuracy = 90.090%
# Epoch: 11, Mini-Batch Completed: 300, Loss: 0.391, Test Accuracy = 90.460%
# Epoch: 11, Mini-Batch Completed: 400, Loss: 0.410, Test Accuracy = 90.330%
# Epoch: 11, Mini-Batch Completed: 500, Loss: 0.404, Test Accuracy = 90.400%
# Epoch: 11, Mini-Batch Completed: 600, Loss: 0.387, Test Accuracy = 91.230%
# Epoch: 11, Mini-Batch Completed: 700, Loss: 0.391, Test Accuracy = 90.400%
# Epoch: 11, Mini-Batch Completed: 800, Loss: 0.377, Test Accuracy = 90.960%
# Epoch: 11, Mini-Batch Completed: 900, Loss: 0.405, Test Accuracy = 90.790%
# Epoch: 11, Mini-Batch Completed: 1000, Loss: 0.414, Test Accuracy = 90.800%
# Epoch: 11, Mini-Batch Completed: 1100, Loss: 0.351, Test Accuracy = 90.480%
# Epoch: 11, Mini-Batch Completed: 1200, Loss: 0.394, Test Accuracy = 89.980%
# Epoch: 11, Mini-Batch Completed: 1300, Loss: 0.451, Test Accuracy = 90.890%
# Epoch: 11, Mini-Batch Completed: 1400, Loss: 0.404, Test Accuracy = 90.410%
# Epoch: 11, Mini-Batch Completed: 1500, Loss: 0.394, Test Accuracy = 90.830%
# Epoch: 11, Mini-Batch Completed: 1600, Loss: 0.381, Test Accuracy = 90.940%
# Epoch: 11, Mini-Batch Completed: 1700, Loss: 0.416, Test Accuracy = 91.100%
# Epoch: 11, Mini-Batch Completed: 1800, Loss: 0.393, Test Accuracy = 90.890%
# Starting Epoch: 12...
# Epoch: 12, Mini-Batch Completed: 100, Loss: 0.368, Test Accuracy = 90.820%
# Epoch: 12, Mini-Batch Completed: 200, Loss: 0.363, Test Accuracy = 91.140%
# Epoch: 12, Mini-Batch Completed: 300, Loss: 0.334, Test Accuracy = 91.400%
# Epoch: 12, Mini-Batch Completed: 400, Loss: 0.394, Test Accuracy = 90.690%
# Epoch: 12, Mini-Batch Completed: 500, Loss: 0.367, Test Accuracy = 91.250%
# Epoch: 12, Mini-Batch Completed: 600, Loss: 0.325, Test Accuracy = 91.220%
# Epoch: 12, Mini-Batch Completed: 700, Loss: 0.398, Test Accuracy = 90.320%
# Epoch: 12, Mini-Batch Completed: 800, Loss: 0.400, Test Accuracy = 90.430%
# Epoch: 12, Mini-Batch Completed: 900, Loss: 0.401, Test Accuracy = 90.890%
# Epoch: 12, Mini-Batch Completed: 1000, Loss: 0.388, Test Accuracy = 89.830%
# Epoch: 12, Mini-Batch Completed: 1100, Loss: 0.352, Test Accuracy = 91.110%
# Epoch: 12, Mini-Batch Completed: 1200, Loss: 0.391, Test Accuracy = 90.600%
# Epoch: 12, Mini-Batch Completed: 1300, Loss: 0.379, Test Accuracy = 90.800%
# Epoch: 12, Mini-Batch Completed: 1400, Loss: 0.408, Test Accuracy = 91.270%
# Epoch: 12, Mini-Batch Completed: 1500, Loss: 0.376, Test Accuracy = 90.910%
# Epoch: 12, Mini-Batch Completed: 1600, Loss: 0.404, Test Accuracy = 91.050%
# Epoch: 12, Mini-Batch Completed: 1700, Loss: 0.354, Test Accuracy = 90.650%
# Epoch: 12, Mini-Batch Completed: 1800, Loss: 0.376, Test Accuracy = 91.310%
# Starting Epoch: 13...
# Epoch: 13, Mini-Batch Completed: 100, Loss: 0.346, Test Accuracy = 91.310%
# Epoch: 13, Mini-Batch Completed: 200, Loss: 0.355, Test Accuracy = 90.870%
# Epoch: 13, Mini-Batch Completed: 300, Loss: 0.344, Test Accuracy = 91.470%
# Epoch: 13, Mini-Batch Completed: 400, Loss: 0.387, Test Accuracy = 91.210%
# Epoch: 13, Mini-Batch Completed: 500, Loss: 0.398, Test Accuracy = 90.990%
# Epoch: 13, Mini-Batch Completed: 600, Loss: 0.354, Test Accuracy = 91.160%
# Epoch: 13, Mini-Batch Completed: 700, Loss: 0.338, Test Accuracy = 91.480%
# Epoch: 13, Mini-Batch Completed: 800, Loss: 0.360, Test Accuracy = 90.630%
# Epoch: 13, Mini-Batch Completed: 900, Loss: 0.384, Test Accuracy = 91.370%
# Epoch: 13, Mini-Batch Completed: 1000, Loss: 0.381, Test Accuracy = 91.100%
# Epoch: 13, Mini-Batch Completed: 1100, Loss: 0.347, Test Accuracy = 91.040%
# Epoch: 13, Mini-Batch Completed: 1200, Loss: 0.335, Test Accuracy = 90.460%
# Epoch: 13, Mini-Batch Completed: 1300, Loss: 0.366, Test Accuracy = 90.360%
# Epoch: 13, Mini-Batch Completed: 1400, Loss: 0.354, Test Accuracy = 91.110%
# Epoch: 13, Mini-Batch Completed: 1500, Loss: 0.340, Test Accuracy = 91.230%
# Epoch: 13, Mini-Batch Completed: 1600, Loss: 0.380, Test Accuracy = 91.640%
# Epoch: 13, Mini-Batch Completed: 1700, Loss: 0.370, Test Accuracy = 90.900%
# Epoch: 13, Mini-Batch Completed: 1800, Loss: 0.367, Test Accuracy = 90.870%
# Starting Epoch: 14...
# Epoch: 14, Mini-Batch Completed: 100, Loss: 0.323, Test Accuracy = 91.290%
# Epoch: 14, Mini-Batch Completed: 200, Loss: 0.316, Test Accuracy = 90.940%
# Epoch: 14, Mini-Batch Completed: 300, Loss: 0.354, Test Accuracy = 91.280%
# Epoch: 14, Mini-Batch Completed: 400, Loss: 0.324, Test Accuracy = 91.200%
# Epoch: 14, Mini-Batch Completed: 500, Loss: 0.338, Test Accuracy = 90.970%
# Epoch: 14, Mini-Batch Completed: 600, Loss: 0.337, Test Accuracy = 90.850%
# Epoch: 14, Mini-Batch Completed: 700, Loss: 0.334, Test Accuracy = 91.350%
# Epoch: 14, Mini-Batch Completed: 800, Loss: 0.370, Test Accuracy = 91.440%
# Epoch: 14, Mini-Batch Completed: 900, Loss: 0.353, Test Accuracy = 91.140%
# Epoch: 14, Mini-Batch Completed: 1000, Loss: 0.351, Test Accuracy = 91.050%
# Epoch: 14, Mini-Batch Completed: 1100, Loss: 0.336, Test Accuracy = 91.310%
# Epoch: 14, Mini-Batch Completed: 1200, Loss: 0.321, Test Accuracy = 91.510%
# Epoch: 14, Mini-Batch Completed: 1300, Loss: 0.358, Test Accuracy = 91.160%
# Epoch: 14, Mini-Batch Completed: 1400, Loss: 0.344, Test Accuracy = 91.500%
# Epoch: 14, Mini-Batch Completed: 1500, Loss: 0.351, Test Accuracy = 91.500%
# Epoch: 14, Mini-Batch Completed: 1600, Loss: 0.340, Test Accuracy = 90.900%
# Epoch: 14, Mini-Batch Completed: 1700, Loss: 0.347, Test Accuracy = 91.360%
# Epoch: 14, Mini-Batch Completed: 1800, Loss: 0.344, Test Accuracy = 91.530%
# Starting Epoch: 15...
# Epoch: 15, Mini-Batch Completed: 100, Loss: 0.310, Test Accuracy = 91.270%
# Epoch: 15, Mini-Batch Completed: 200, Loss: 0.332, Test Accuracy = 90.910%
# Epoch: 15, Mini-Batch Completed: 300, Loss: 0.292, Test Accuracy = 91.210%
# Epoch: 15, Mini-Batch Completed: 400, Loss: 0.306, Test Accuracy = 91.530%
# Epoch: 15, Mini-Batch Completed: 500, Loss: 0.312, Test Accuracy = 91.200%
# Epoch: 15, Mini-Batch Completed: 600, Loss: 0.319, Test Accuracy = 91.570%
# Epoch: 15, Mini-Batch Completed: 700, Loss: 0.337, Test Accuracy = 91.200%
# Epoch: 15, Mini-Batch Completed: 800, Loss: 0.309, Test Accuracy = 91.170%
# Epoch: 15, Mini-Batch Completed: 900, Loss: 0.354, Test Accuracy = 90.880%
# Epoch: 15, Mini-Batch Completed: 1000, Loss: 0.336, Test Accuracy = 90.630%
# Epoch: 15, Mini-Batch Completed: 1100, Loss: 0.317, Test Accuracy = 91.160%
# Epoch: 15, Mini-Batch Completed: 1200, Loss: 0.294, Test Accuracy = 91.750%
# Epoch: 15, Mini-Batch Completed: 1300, Loss: 0.361, Test Accuracy = 91.150%
# Epoch: 15, Mini-Batch Completed: 1400, Loss: 0.290, Test Accuracy = 91.660%
# Epoch: 15, Mini-Batch Completed: 1500, Loss: 0.307, Test Accuracy = 91.590%
# Epoch: 15, Mini-Batch Completed: 1600, Loss: 0.350, Test Accuracy = 91.750%
# Epoch: 15, Mini-Batch Completed: 1700, Loss: 0.333, Test Accuracy = 91.480%
# Epoch: 15, Mini-Batch Completed: 1800, Loss: 0.316, Test Accuracy = 91.300%
# Finished Training

# %%
correct = 0
total = 0

with torch.no_grad():
  for data in testloader:
    images, labels = data
    images = images.to(device)
    labels = labels.to(device)
    outputs = net(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()

accuracy = 100*correct/total
print(f'Accuracy of the network on the 10000 test images: {accuracy:.4}%')
# Out:
# Accuracy of the network on the 10000 test images: 91.41%

# %%
fig, ax1 = plt.subplots()

plt.title("Accuracy & Loss vs Epoch Mini-Batches")
plt.xticks(rotation=45)
ax2 = ax1.twinx()
ax1.plot(epoch_log, loss_log, 'g-')
ax2.plot(epoch_log, accuracy_log, 'b-')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='g')
ax2.set_ylabel('Test Accuracy', color='b')

plt.show()

# %%
data_aug_transform = transforms.Compose([
    transforms.RandomAffine(degrees=10, translate=(0.05, 0.05), shear=5),
    transforms.ColorJitter(hue=0.05, saturation=0.05),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.Grayscale(num_output_channels=1)
])

# %%
from matplotlib.pyplot import figure, imshow, axis
from matplotlib.image import imread

def showAugmentations(image, augmentations = 6):
    fig = figure()
    for i in range(augmentations):
        a = fig.add_subplot(1,augmentations,i+1)
        img = data_aug_transform(image)
        imshow(img ,cmap='Greys_r')
        axis('off')

# %%
image = trainset.data[0].numpy()
img_pil = PIL.Image.fromarray(image)
showAugmentations(img_pil, 8)

# %% [markdown]
# ## Regularization

# %%
data_transforms = {
    "train": transforms.Compose([
        transforms.RandomAffine(degrees=10, translate=(0.05, 0.05), shear=5),
        transforms.ColorJitter(hue=0.05, saturation=0.05),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.Grayscale(num_output_channels=1),
        transforms.ToTensor(),
        transforms.Normalize((0.5, ), (0.5, ))
    ]),
    "val": transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, ), (0.5, ))
    ])
}

# %%
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                        download=True, transform=data_transforms['train'])

testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                       download=True, transform=data_transforms['val'])

trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False, num_workers=2)

# %%
class net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.conv1 = nn.Conv2d(1, 32, 3)
    self.conv1_bn = nn.BatchNorm2d(32)
    self.conv2 = nn.Conv2d(32, 64, 3)
    self.conv2_bn = nn.BatchNorm2d(64)
    self.pool = nn.MaxPool2d(2, 2)
    self.fc1 = nn.Linear(64*12*12, 128)
    self.fc2 = nn.Linear(128, 10)
    self.dropout = nn.Dropout(0.2)

  def forward(self, x):
    x = F.relu(self.conv1_bn(self.conv1(x)))
    x = self.dropout(x)
    x = self.dropout(F.relu(self.conv2_bn(self.conv2(x))))

    x = self.pool(x)
    x = x.view(-1, 64*12*12)
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return x

net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=0.001)

# %%
epochs = 15

epoch_log = []
loss_log = []
accuracy_log = []

for epoch in range(epochs):
  print(f"Strating Epoch: {epoch+1}...")
  running_loss = 0.0
  for i, data in enumerate(trainloader, 0):
    inputs, labels = data
    inputs = inputs.to(device)
    labels = labels.to(device)
    optimizer.zero_grad()
    outputs = net(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    running_loss += loss.item()
    if i%100 == 99:
      correct = 0
      total = 0

      with torch.no_grad():
        for data in testloader:
          inputs, labels = data
          inputs = inputs.to(device)
          labels = labels.to(device)
          outputs = net(inputs)
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()
        accuracy = 100*correct/total
        epoch_num = epoch+1
        actual_loss = running_loss/50
        print(f'Epoch: {epoch_num}, Mini-Batches Completed: {(i+1)}, Loss: {actual_loss:.3f}, Test Accuracy = {accuracy:.3f}%')
        running_loss = 0.0

  epoch_log.append(epoch_num)
  loss_log.append(actual_loss)
  accuracy_log.append(accuracy)

print("Finished Training!")
# Out:
# Strating Epoch: 1...
# Epoch: 1, Mini-Batches Completed: 100, Loss: 2.799, Test Accuracy = 66.470%
# Epoch: 1, Mini-Batches Completed: 200, Loss: 2.023, Test Accuracy = 69.380%
# Epoch: 1, Mini-Batches Completed: 300, Loss: 1.798, Test Accuracy = 71.120%
# Epoch: 1, Mini-Batches Completed: 400, Loss: 1.730, Test Accuracy = 72.180%
# Epoch: 1, Mini-Batches Completed: 500, Loss: 1.701, Test Accuracy = 71.100%
# Epoch: 1, Mini-Batches Completed: 600, Loss: 1.576, Test Accuracy = 73.710%
# Epoch: 1, Mini-Batches Completed: 700, Loss: 1.519, Test Accuracy = 72.390%
# Epoch: 1, Mini-Batches Completed: 800, Loss: 1.532, Test Accuracy = 74.720%
# Epoch: 1, Mini-Batches Completed: 900, Loss: 1.469, Test Accuracy = 70.830%
# Epoch: 1, Mini-Batches Completed: 1000, Loss: 1.461, Test Accuracy = 74.860%
# Epoch: 1, Mini-Batches Completed: 1100, Loss: 1.367, Test Accuracy = 71.880%
# Epoch: 1, Mini-Batches Completed: 1200, Loss: 1.342, Test Accuracy = 74.870%
# Epoch: 1, Mini-Batches Completed: 1300, Loss: 1.383, Test Accuracy = 76.120%
# Epoch: 1, Mini-Batches Completed: 1400, Loss: 1.367, Test Accuracy = 73.350%
# Epoch: 1, Mini-Batches Completed: 1500, Loss: 1.382, Test Accuracy = 77.180%
# Epoch: 1, Mini-Batches Completed: 1600, Loss: 1.310, Test Accuracy = 77.290%
# Epoch: 1, Mini-Batches Completed: 1700, Loss: 1.280, Test Accuracy = 75.210%
# Epoch: 1, Mini-Batches Completed: 1800, Loss: 1.267, Test Accuracy = 77.680%
# Strating Epoch: 2...
# Epoch: 2, Mini-Batches Completed: 100, Loss: 1.334, Test Accuracy = 78.070%
# Epoch: 2, Mini-Batches Completed: 200, Loss: 1.219, Test Accuracy = 77.880%
# Epoch: 2, Mini-Batches Completed: 300, Loss: 1.267, Test Accuracy = 76.730%
# Epoch: 2, Mini-Batches Completed: 400, Loss: 1.283, Test Accuracy = 78.920%
# Epoch: 2, Mini-Batches Completed: 500, Loss: 1.227, Test Accuracy = 79.480%
# Epoch: 2, Mini-Batches Completed: 600, Loss: 1.194, Test Accuracy = 77.420%
# Epoch: 2, Mini-Batches Completed: 700, Loss: 1.169, Test Accuracy = 79.010%
# Epoch: 2, Mini-Batches Completed: 800, Loss: 1.228, Test Accuracy = 78.810%
# Epoch: 2, Mini-Batches Completed: 900, Loss: 1.157, Test Accuracy = 79.810%
# Epoch: 2, Mini-Batches Completed: 1000, Loss: 1.191, Test Accuracy = 79.250%
# Epoch: 2, Mini-Batches Completed: 1100, Loss: 1.181, Test Accuracy = 80.080%
# Epoch: 2, Mini-Batches Completed: 1200, Loss: 1.241, Test Accuracy = 79.650%
# Epoch: 2, Mini-Batches Completed: 1300, Loss: 1.189, Test Accuracy = 79.210%
# Epoch: 2, Mini-Batches Completed: 1400, Loss: 1.127, Test Accuracy = 79.770%
# Epoch: 2, Mini-Batches Completed: 1500, Loss: 1.154, Test Accuracy = 79.740%
# Epoch: 2, Mini-Batches Completed: 1600, Loss: 1.172, Test Accuracy = 79.200%
# Epoch: 2, Mini-Batches Completed: 1700, Loss: 1.180, Test Accuracy = 80.590%
# Epoch: 2, Mini-Batches Completed: 1800, Loss: 1.092, Test Accuracy = 80.390%
# Strating Epoch: 3...
# Epoch: 3, Mini-Batches Completed: 100, Loss: 1.091, Test Accuracy = 81.360%
# Epoch: 3, Mini-Batches Completed: 200, Loss: 1.157, Test Accuracy = 80.570%
# Epoch: 3, Mini-Batches Completed: 300, Loss: 1.095, Test Accuracy = 81.630%
# Epoch: 3, Mini-Batches Completed: 400, Loss: 1.086, Test Accuracy = 81.470%
# Epoch: 3, Mini-Batches Completed: 500, Loss: 1.132, Test Accuracy = 81.520%
# Epoch: 3, Mini-Batches Completed: 600, Loss: 1.121, Test Accuracy = 80.780%
# Epoch: 3, Mini-Batches Completed: 700, Loss: 1.083, Test Accuracy = 81.110%
# Epoch: 3, Mini-Batches Completed: 800, Loss: 1.057, Test Accuracy = 81.170%
# Epoch: 3, Mini-Batches Completed: 900, Loss: 1.053, Test Accuracy = 80.950%
# Epoch: 3, Mini-Batches Completed: 1000, Loss: 1.072, Test Accuracy = 81.320%
# Epoch: 3, Mini-Batches Completed: 1100, Loss: 1.065, Test Accuracy = 82.150%
# Epoch: 3, Mini-Batches Completed: 1200, Loss: 1.070, Test Accuracy = 79.110%
# Epoch: 3, Mini-Batches Completed: 1300, Loss: 1.109, Test Accuracy = 82.670%
# Epoch: 3, Mini-Batches Completed: 1400, Loss: 1.050, Test Accuracy = 81.990%
# Epoch: 3, Mini-Batches Completed: 1500, Loss: 1.063, Test Accuracy = 82.090%
# Epoch: 3, Mini-Batches Completed: 1600, Loss: 1.065, Test Accuracy = 82.280%
# Epoch: 3, Mini-Batches Completed: 1700, Loss: 1.113, Test Accuracy = 82.210%
# Epoch: 3, Mini-Batches Completed: 1800, Loss: 1.101, Test Accuracy = 82.900%
# Strating Epoch: 4...
# Epoch: 4, Mini-Batches Completed: 100, Loss: 1.019, Test Accuracy = 82.930%
# Epoch: 4, Mini-Batches Completed: 200, Loss: 1.060, Test Accuracy = 82.380%
# Epoch: 4, Mini-Batches Completed: 300, Loss: 0.987, Test Accuracy = 81.990%
# Epoch: 4, Mini-Batches Completed: 400, Loss: 1.033, Test Accuracy = 81.680%
# Epoch: 4, Mini-Batches Completed: 500, Loss: 1.041, Test Accuracy = 82.550%
# Epoch: 4, Mini-Batches Completed: 600, Loss: 0.949, Test Accuracy = 82.880%
# Epoch: 4, Mini-Batches Completed: 700, Loss: 1.035, Test Accuracy = 82.080%
# Epoch: 4, Mini-Batches Completed: 800, Loss: 1.004, Test Accuracy = 82.580%
# Epoch: 4, Mini-Batches Completed: 900, Loss: 1.005, Test Accuracy = 82.410%
# Epoch: 4, Mini-Batches Completed: 1000, Loss: 1.043, Test Accuracy = 83.670%
# Epoch: 4, Mini-Batches Completed: 1100, Loss: 1.052, Test Accuracy = 82.870%
# Epoch: 4, Mini-Batches Completed: 1200, Loss: 0.992, Test Accuracy = 83.410%
# Epoch: 4, Mini-Batches Completed: 1300, Loss: 0.957, Test Accuracy = 84.050%
# Epoch: 4, Mini-Batches Completed: 1400, Loss: 0.973, Test Accuracy = 82.540%
# Epoch: 4, Mini-Batches Completed: 1500, Loss: 1.015, Test Accuracy = 84.130%
# Epoch: 4, Mini-Batches Completed: 1600, Loss: 1.071, Test Accuracy = 83.430%
# Epoch: 4, Mini-Batches Completed: 1700, Loss: 0.992, Test Accuracy = 83.850%
# Epoch: 4, Mini-Batches Completed: 1800, Loss: 0.971, Test Accuracy = 83.970%
# Strating Epoch: 5...
# Epoch: 5, Mini-Batches Completed: 100, Loss: 1.001, Test Accuracy = 84.600%
# Epoch: 5, Mini-Batches Completed: 200, Loss: 0.958, Test Accuracy = 83.190%
# Epoch: 5, Mini-Batches Completed: 300, Loss: 0.965, Test Accuracy = 84.030%
# Epoch: 5, Mini-Batches Completed: 400, Loss: 0.991, Test Accuracy = 84.160%
# Epoch: 5, Mini-Batches Completed: 500, Loss: 0.979, Test Accuracy = 83.240%
# Epoch: 5, Mini-Batches Completed: 600, Loss: 0.974, Test Accuracy = 83.780%
# Epoch: 5, Mini-Batches Completed: 700, Loss: 0.905, Test Accuracy = 83.090%
# Epoch: 5, Mini-Batches Completed: 800, Loss: 0.980, Test Accuracy = 83.100%
# Epoch: 5, Mini-Batches Completed: 900, Loss: 0.936, Test Accuracy = 83.830%
# Epoch: 5, Mini-Batches Completed: 1000, Loss: 0.987, Test Accuracy = 84.540%
# Epoch: 5, Mini-Batches Completed: 1100, Loss: 0.950, Test Accuracy = 84.450%
# Epoch: 5, Mini-Batches Completed: 1200, Loss: 0.980, Test Accuracy = 84.570%
# Epoch: 5, Mini-Batches Completed: 1300, Loss: 0.984, Test Accuracy = 85.190%
# Epoch: 5, Mini-Batches Completed: 1400, Loss: 0.958, Test Accuracy = 83.220%
# Epoch: 5, Mini-Batches Completed: 1500, Loss: 0.924, Test Accuracy = 84.800%
# Epoch: 5, Mini-Batches Completed: 1600, Loss: 0.930, Test Accuracy = 83.720%
# Epoch: 5, Mini-Batches Completed: 1700, Loss: 0.922, Test Accuracy = 84.960%
# Epoch: 5, Mini-Batches Completed: 1800, Loss: 0.960, Test Accuracy = 83.170%
# Strating Epoch: 6...
# Epoch: 6, Mini-Batches Completed: 100, Loss: 0.953, Test Accuracy = 85.510%
# Epoch: 6, Mini-Batches Completed: 200, Loss: 0.935, Test Accuracy = 83.580%
# Epoch: 6, Mini-Batches Completed: 300, Loss: 0.904, Test Accuracy = 84.660%
# Epoch: 6, Mini-Batches Completed: 400, Loss: 0.955, Test Accuracy = 84.570%
# Epoch: 6, Mini-Batches Completed: 500, Loss: 0.907, Test Accuracy = 85.160%
# Epoch: 6, Mini-Batches Completed: 600, Loss: 0.904, Test Accuracy = 84.590%
# Epoch: 6, Mini-Batches Completed: 700, Loss: 0.956, Test Accuracy = 85.260%
# Epoch: 6, Mini-Batches Completed: 800, Loss: 0.908, Test Accuracy = 85.130%
# Epoch: 6, Mini-Batches Completed: 900, Loss: 0.928, Test Accuracy = 85.010%
# Epoch: 6, Mini-Batches Completed: 1000, Loss: 0.895, Test Accuracy = 85.050%
# Epoch: 6, Mini-Batches Completed: 1100, Loss: 0.974, Test Accuracy = 84.910%
# Epoch: 6, Mini-Batches Completed: 1200, Loss: 0.895, Test Accuracy = 85.090%
# Epoch: 6, Mini-Batches Completed: 1300, Loss: 0.867, Test Accuracy = 84.370%
# Epoch: 6, Mini-Batches Completed: 1400, Loss: 0.892, Test Accuracy = 85.430%
# Epoch: 6, Mini-Batches Completed: 1500, Loss: 0.847, Test Accuracy = 84.530%
# Epoch: 6, Mini-Batches Completed: 1600, Loss: 0.879, Test Accuracy = 85.380%
# Epoch: 6, Mini-Batches Completed: 1700, Loss: 0.908, Test Accuracy = 81.930%
# Epoch: 6, Mini-Batches Completed: 1800, Loss: 0.916, Test Accuracy = 84.460%
# Strating Epoch: 7...
# Epoch: 7, Mini-Batches Completed: 100, Loss: 0.876, Test Accuracy = 83.420%
# Epoch: 7, Mini-Batches Completed: 200, Loss: 0.873, Test Accuracy = 85.470%
# Epoch: 7, Mini-Batches Completed: 300, Loss: 0.913, Test Accuracy = 84.990%
# Epoch: 7, Mini-Batches Completed: 400, Loss: 0.857, Test Accuracy = 86.420%
# Epoch: 7, Mini-Batches Completed: 500, Loss: 0.889, Test Accuracy = 85.730%
# Epoch: 7, Mini-Batches Completed: 600, Loss: 0.836, Test Accuracy = 85.210%
# Epoch: 7, Mini-Batches Completed: 700, Loss: 0.924, Test Accuracy = 85.810%
# Epoch: 7, Mini-Batches Completed: 800, Loss: 0.856, Test Accuracy = 85.800%
# Epoch: 7, Mini-Batches Completed: 900, Loss: 0.918, Test Accuracy = 85.320%
# Epoch: 7, Mini-Batches Completed: 1000, Loss: 0.872, Test Accuracy = 85.460%
# Epoch: 7, Mini-Batches Completed: 1100, Loss: 0.889, Test Accuracy = 85.770%
# Epoch: 7, Mini-Batches Completed: 1200, Loss: 0.868, Test Accuracy = 85.800%
# Epoch: 7, Mini-Batches Completed: 1300, Loss: 0.891, Test Accuracy = 84.520%
# Epoch: 7, Mini-Batches Completed: 1400, Loss: 0.894, Test Accuracy = 85.710%
# Epoch: 7, Mini-Batches Completed: 1500, Loss: 0.869, Test Accuracy = 85.670%
# Epoch: 7, Mini-Batches Completed: 1600, Loss: 0.887, Test Accuracy = 86.010%
# Epoch: 7, Mini-Batches Completed: 1700, Loss: 0.829, Test Accuracy = 85.040%
# Epoch: 7, Mini-Batches Completed: 1800, Loss: 0.881, Test Accuracy = 84.560%
# Strating Epoch: 8...
# Epoch: 8, Mini-Batches Completed: 100, Loss: 0.834, Test Accuracy = 85.780%
# Epoch: 8, Mini-Batches Completed: 200, Loss: 0.853, Test Accuracy = 85.690%
# Epoch: 8, Mini-Batches Completed: 300, Loss: 0.814, Test Accuracy = 86.410%
# Epoch: 8, Mini-Batches Completed: 400, Loss: 0.879, Test Accuracy = 85.490%
# Epoch: 8, Mini-Batches Completed: 500, Loss: 0.888, Test Accuracy = 85.020%
# Epoch: 8, Mini-Batches Completed: 600, Loss: 0.852, Test Accuracy = 84.780%
# Epoch: 8, Mini-Batches Completed: 700, Loss: 0.868, Test Accuracy = 85.770%
# Epoch: 8, Mini-Batches Completed: 800, Loss: 0.846, Test Accuracy = 86.860%
# Epoch: 8, Mini-Batches Completed: 900, Loss: 0.857, Test Accuracy = 86.870%
# Epoch: 8, Mini-Batches Completed: 1000, Loss: 0.888, Test Accuracy = 86.430%
# Epoch: 8, Mini-Batches Completed: 1100, Loss: 0.833, Test Accuracy = 86.100%
# Epoch: 8, Mini-Batches Completed: 1200, Loss: 0.831, Test Accuracy = 85.810%
# Epoch: 8, Mini-Batches Completed: 1300, Loss: 0.779, Test Accuracy = 85.620%
# Epoch: 8, Mini-Batches Completed: 1400, Loss: 0.850, Test Accuracy = 86.330%
# Epoch: 8, Mini-Batches Completed: 1500, Loss: 0.838, Test Accuracy = 86.350%
# Epoch: 8, Mini-Batches Completed: 1600, Loss: 0.860, Test Accuracy = 86.640%
# Epoch: 8, Mini-Batches Completed: 1700, Loss: 0.842, Test Accuracy = 86.860%
# Epoch: 8, Mini-Batches Completed: 1800, Loss: 0.848, Test Accuracy = 87.030%
# Strating Epoch: 9...
# Epoch: 9, Mini-Batches Completed: 100, Loss: 0.866, Test Accuracy = 86.270%
# Epoch: 9, Mini-Batches Completed: 200, Loss: 0.783, Test Accuracy = 85.140%
# Epoch: 9, Mini-Batches Completed: 300, Loss: 0.842, Test Accuracy = 86.240%
# Epoch: 9, Mini-Batches Completed: 400, Loss: 0.830, Test Accuracy = 86.470%
# Epoch: 9, Mini-Batches Completed: 500, Loss: 0.775, Test Accuracy = 86.900%
# Epoch: 9, Mini-Batches Completed: 600, Loss: 0.857, Test Accuracy = 86.450%
# Epoch: 9, Mini-Batches Completed: 700, Loss: 0.818, Test Accuracy = 87.000%
# Epoch: 9, Mini-Batches Completed: 800, Loss: 0.862, Test Accuracy = 86.010%
# Epoch: 9, Mini-Batches Completed: 900, Loss: 0.835, Test Accuracy = 84.590%
# Epoch: 9, Mini-Batches Completed: 1000, Loss: 0.788, Test Accuracy = 86.810%
# Epoch: 9, Mini-Batches Completed: 1100, Loss: 0.820, Test Accuracy = 87.070%
# Epoch: 9, Mini-Batches Completed: 1200, Loss: 0.778, Test Accuracy = 86.670%
# Epoch: 9, Mini-Batches Completed: 1300, Loss: 0.803, Test Accuracy = 87.030%
# Epoch: 9, Mini-Batches Completed: 1400, Loss: 0.828, Test Accuracy = 86.920%
# Epoch: 9, Mini-Batches Completed: 1500, Loss: 0.801, Test Accuracy = 86.760%
# Epoch: 9, Mini-Batches Completed: 1600, Loss: 0.782, Test Accuracy = 86.910%
# Epoch: 9, Mini-Batches Completed: 1700, Loss: 0.799, Test Accuracy = 86.340%
# Epoch: 9, Mini-Batches Completed: 1800, Loss: 0.819, Test Accuracy = 86.960%
# Strating Epoch: 10...
# Epoch: 10, Mini-Batches Completed: 100, Loss: 0.779, Test Accuracy = 87.570%
# Epoch: 10, Mini-Batches Completed: 200, Loss: 0.832, Test Accuracy = 87.110%
# Epoch: 10, Mini-Batches Completed: 300, Loss: 0.742, Test Accuracy = 86.710%
# Epoch: 10, Mini-Batches Completed: 400, Loss: 0.763, Test Accuracy = 87.220%
# Epoch: 10, Mini-Batches Completed: 500, Loss: 0.808, Test Accuracy = 87.300%
# Epoch: 10, Mini-Batches Completed: 600, Loss: 0.850, Test Accuracy = 87.800%
# Epoch: 10, Mini-Batches Completed: 700, Loss: 0.755, Test Accuracy = 87.430%
# Epoch: 10, Mini-Batches Completed: 800, Loss: 0.817, Test Accuracy = 86.580%
# Epoch: 10, Mini-Batches Completed: 900, Loss: 0.801, Test Accuracy = 87.310%
# Epoch: 10, Mini-Batches Completed: 1000, Loss: 0.759, Test Accuracy = 86.730%
# Epoch: 10, Mini-Batches Completed: 1100, Loss: 0.829, Test Accuracy = 87.740%
# Epoch: 10, Mini-Batches Completed: 1200, Loss: 0.807, Test Accuracy = 87.250%
# Epoch: 10, Mini-Batches Completed: 1300, Loss: 0.808, Test Accuracy = 87.000%
# Epoch: 10, Mini-Batches Completed: 1400, Loss: 0.839, Test Accuracy = 86.840%
# Epoch: 10, Mini-Batches Completed: 1500, Loss: 0.798, Test Accuracy = 86.960%
# Epoch: 10, Mini-Batches Completed: 1600, Loss: 0.786, Test Accuracy = 87.590%
# Epoch: 10, Mini-Batches Completed: 1700, Loss: 0.793, Test Accuracy = 86.630%
# Epoch: 10, Mini-Batches Completed: 1800, Loss: 0.739, Test Accuracy = 87.400%
# Strating Epoch: 11...
# Epoch: 11, Mini-Batches Completed: 100, Loss: 0.752, Test Accuracy = 87.630%
# Epoch: 11, Mini-Batches Completed: 200, Loss: 0.761, Test Accuracy = 87.780%
# Epoch: 11, Mini-Batches Completed: 300, Loss: 0.828, Test Accuracy = 87.200%
# Epoch: 11, Mini-Batches Completed: 400, Loss: 0.765, Test Accuracy = 87.330%
# Epoch: 11, Mini-Batches Completed: 500, Loss: 0.774, Test Accuracy = 88.010%
# Epoch: 11, Mini-Batches Completed: 600, Loss: 0.765, Test Accuracy = 86.450%
# Epoch: 11, Mini-Batches Completed: 700, Loss: 0.759, Test Accuracy = 87.700%
# Epoch: 11, Mini-Batches Completed: 800, Loss: 0.752, Test Accuracy = 87.480%
# Epoch: 11, Mini-Batches Completed: 900, Loss: 0.801, Test Accuracy = 87.850%
# Epoch: 11, Mini-Batches Completed: 1000, Loss: 0.767, Test Accuracy = 88.110%
# Epoch: 11, Mini-Batches Completed: 1100, Loss: 0.749, Test Accuracy = 87.750%
# Epoch: 11, Mini-Batches Completed: 1200, Loss: 0.823, Test Accuracy = 87.020%
# Epoch: 11, Mini-Batches Completed: 1300, Loss: 0.790, Test Accuracy = 87.820%
# Epoch: 11, Mini-Batches Completed: 1400, Loss: 0.773, Test Accuracy = 87.530%
# Epoch: 11, Mini-Batches Completed: 1500, Loss: 0.778, Test Accuracy = 88.040%
# Epoch: 11, Mini-Batches Completed: 1600, Loss: 0.749, Test Accuracy = 88.230%
# Epoch: 11, Mini-Batches Completed: 1700, Loss: 0.765, Test Accuracy = 88.000%
# Epoch: 11, Mini-Batches Completed: 1800, Loss: 0.740, Test Accuracy = 87.820%
# Strating Epoch: 12...
# Epoch: 12, Mini-Batches Completed: 100, Loss: 0.817, Test Accuracy = 87.700%
# Epoch: 12, Mini-Batches Completed: 200, Loss: 0.770, Test Accuracy = 87.620%
# Epoch: 12, Mini-Batches Completed: 300, Loss: 0.757, Test Accuracy = 88.220%
# Epoch: 12, Mini-Batches Completed: 400, Loss: 0.718, Test Accuracy = 87.620%
# Epoch: 12, Mini-Batches Completed: 500, Loss: 0.757, Test Accuracy = 87.880%
# Epoch: 12, Mini-Batches Completed: 600, Loss: 0.761, Test Accuracy = 88.060%
# Epoch: 12, Mini-Batches Completed: 700, Loss: 0.786, Test Accuracy = 87.650%
# Epoch: 12, Mini-Batches Completed: 800, Loss: 0.726, Test Accuracy = 87.430%
# Epoch: 12, Mini-Batches Completed: 900, Loss: 0.760, Test Accuracy = 87.790%
# Epoch: 12, Mini-Batches Completed: 1000, Loss: 0.756, Test Accuracy = 87.630%
# Epoch: 12, Mini-Batches Completed: 1100, Loss: 0.746, Test Accuracy = 87.730%
# Epoch: 12, Mini-Batches Completed: 1200, Loss: 0.769, Test Accuracy = 87.660%
# Epoch: 12, Mini-Batches Completed: 1300, Loss: 0.711, Test Accuracy = 88.370%
# Epoch: 12, Mini-Batches Completed: 1400, Loss: 0.740, Test Accuracy = 87.640%
# Epoch: 12, Mini-Batches Completed: 1500, Loss: 0.747, Test Accuracy = 88.020%
# Epoch: 12, Mini-Batches Completed: 1600, Loss: 0.748, Test Accuracy = 87.840%
# Epoch: 12, Mini-Batches Completed: 1700, Loss: 0.751, Test Accuracy = 88.020%
# Epoch: 12, Mini-Batches Completed: 1800, Loss: 0.775, Test Accuracy = 88.570%
# Strating Epoch: 13...
# Epoch: 13, Mini-Batches Completed: 100, Loss: 0.693, Test Accuracy = 88.030%
# Epoch: 13, Mini-Batches Completed: 200, Loss: 0.750, Test Accuracy = 87.650%
# Epoch: 13, Mini-Batches Completed: 300, Loss: 0.700, Test Accuracy = 87.690%
# Epoch: 13, Mini-Batches Completed: 400, Loss: 0.779, Test Accuracy = 87.580%
# Epoch: 13, Mini-Batches Completed: 500, Loss: 0.798, Test Accuracy = 88.010%
# Epoch: 13, Mini-Batches Completed: 600, Loss: 0.672, Test Accuracy = 87.330%
# Epoch: 13, Mini-Batches Completed: 700, Loss: 0.756, Test Accuracy = 87.310%
# Epoch: 13, Mini-Batches Completed: 800, Loss: 0.746, Test Accuracy = 88.100%
# Epoch: 13, Mini-Batches Completed: 900, Loss: 0.807, Test Accuracy = 86.930%
# Epoch: 13, Mini-Batches Completed: 1000, Loss: 0.739, Test Accuracy = 87.270%
# Epoch: 13, Mini-Batches Completed: 1100, Loss: 0.669, Test Accuracy = 86.460%
# Epoch: 13, Mini-Batches Completed: 1200, Loss: 0.689, Test Accuracy = 87.520%
# Epoch: 13, Mini-Batches Completed: 1300, Loss: 0.745, Test Accuracy = 88.100%
# Epoch: 13, Mini-Batches Completed: 1400, Loss: 0.783, Test Accuracy = 88.240%
# Epoch: 13, Mini-Batches Completed: 1500, Loss: 0.720, Test Accuracy = 88.400%
# Epoch: 13, Mini-Batches Completed: 1600, Loss: 0.729, Test Accuracy = 87.640%
# Epoch: 13, Mini-Batches Completed: 1700, Loss: 0.731, Test Accuracy = 88.200%
# Epoch: 13, Mini-Batches Completed: 1800, Loss: 0.712, Test Accuracy = 88.030%
# Strating Epoch: 14...
# Epoch: 14, Mini-Batches Completed: 100, Loss: 0.726, Test Accuracy = 87.340%
# Epoch: 14, Mini-Batches Completed: 200, Loss: 0.727, Test Accuracy = 87.970%
# Epoch: 14, Mini-Batches Completed: 300, Loss: 0.683, Test Accuracy = 87.680%
# Epoch: 14, Mini-Batches Completed: 400, Loss: 0.754, Test Accuracy = 88.350%
# Epoch: 14, Mini-Batches Completed: 500, Loss: 0.728, Test Accuracy = 88.060%
# Epoch: 14, Mini-Batches Completed: 600, Loss: 0.736, Test Accuracy = 88.250%
# Epoch: 14, Mini-Batches Completed: 700, Loss: 0.753, Test Accuracy = 88.220%
# Epoch: 14, Mini-Batches Completed: 800, Loss: 0.721, Test Accuracy = 87.580%
# Epoch: 14, Mini-Batches Completed: 900, Loss: 0.687, Test Accuracy = 88.560%
# Epoch: 14, Mini-Batches Completed: 1000, Loss: 0.700, Test Accuracy = 87.990%
# Epoch: 14, Mini-Batches Completed: 1100, Loss: 0.746, Test Accuracy = 87.730%
# Epoch: 14, Mini-Batches Completed: 1200, Loss: 0.706, Test Accuracy = 88.310%
# Epoch: 14, Mini-Batches Completed: 1300, Loss: 0.721, Test Accuracy = 88.680%
# Epoch: 14, Mini-Batches Completed: 1400, Loss: 0.683, Test Accuracy = 87.920%
# Epoch: 14, Mini-Batches Completed: 1500, Loss: 0.727, Test Accuracy = 86.900%
# Epoch: 14, Mini-Batches Completed: 1600, Loss: 0.708, Test Accuracy = 88.270%
# Epoch: 14, Mini-Batches Completed: 1700, Loss: 0.755, Test Accuracy = 87.780%
# Epoch: 14, Mini-Batches Completed: 1800, Loss: 0.722, Test Accuracy = 88.800%
# Strating Epoch: 15...
# Epoch: 15, Mini-Batches Completed: 100, Loss: 0.707, Test Accuracy = 88.120%
# Epoch: 15, Mini-Batches Completed: 200, Loss: 0.652, Test Accuracy = 88.510%
# Epoch: 15, Mini-Batches Completed: 300, Loss: 0.668, Test Accuracy = 88.610%
# Epoch: 15, Mini-Batches Completed: 400, Loss: 0.715, Test Accuracy = 87.830%
# Epoch: 15, Mini-Batches Completed: 500, Loss: 0.695, Test Accuracy = 87.500%
# Epoch: 15, Mini-Batches Completed: 600, Loss: 0.746, Test Accuracy = 88.410%
# Epoch: 15, Mini-Batches Completed: 700, Loss: 0.729, Test Accuracy = 88.090%
# Epoch: 15, Mini-Batches Completed: 800, Loss: 0.745, Test Accuracy = 87.750%
# Epoch: 15, Mini-Batches Completed: 900, Loss: 0.712, Test Accuracy = 87.900%
# Epoch: 15, Mini-Batches Completed: 1000, Loss: 0.686, Test Accuracy = 88.210%
# Epoch: 15, Mini-Batches Completed: 1100, Loss: 0.745, Test Accuracy = 88.080%
# Epoch: 15, Mini-Batches Completed: 1200, Loss: 0.755, Test Accuracy = 88.080%
# Epoch: 15, Mini-Batches Completed: 1300, Loss: 0.713, Test Accuracy = 87.780%
# Epoch: 15, Mini-Batches Completed: 1400, Loss: 0.700, Test Accuracy = 87.490%
# Epoch: 15, Mini-Batches Completed: 1500, Loss: 0.732, Test Accuracy = 88.030%
# Epoch: 15, Mini-Batches Completed: 1600, Loss: 0.701, Test Accuracy = 88.640%
# Epoch: 15, Mini-Batches Completed: 1700, Loss: 0.675, Test Accuracy = 88.120%
# Epoch: 15, Mini-Batches Completed: 1800, Loss: 0.689, Test Accuracy = 88.820%
# Finished Training!

# %%
correct = 0
total = 0

with torch.no_grad():
    for data in testloader:
        images, labels = data
        # Move our data to GPU
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy of the network on the 10000 test images: {accuracy:.4}%')
# Out:
# Accuracy of the network on the 10000 test images: 88.6%

# %%
fig, ax1 = plt.subplots()

plt.title("Accuracy & Loss vs Epoch Mini-Batches")
plt.xticks(rotation=45)

ax2 = ax1.twinx()

ax1.plot(epoch_log, loss_log, 'g-')
ax2.plot(epoch_log, accuracy_log, 'b-')

ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='g')
ax2.set_ylabel('Test Accuracy', color='b')

plt.show()
